# %% [markdown]
# OBJECTIF

# %% [markdown]
# Représenter, à partir de données expérimentales variées, l’évolution des grandeurs énergétiques d’un système en mouvement dans un champ uniforme à l’aide d’un langage de programmation ou d’un tableur

# %% [markdown]
# # 1er OBJECTIF
# -     Compléter le script avec vos mesures
# -     Compléter la ligne 15  afin de calculer la vitesse selon y
# -     Compléter les lignes afin de calculer Epi, Eci et Emi

# %%
#Etude énergétique  du lancer d'un bérêt
import matplotlib.pyplot as plt
import numpy as np
#Initialisation des séries à 0
V,tc,Ec,Ep,Em = [0],[0],[0],[0],[0]
m=float(input("Quelle est la masse du mobile étudié en kg ? "))
# Valeurs ( séparées par des virgules) des instants,t en ms considérés
t =np.array([................................................................])
t=t/1000
#Valeurs de l'altitude z de chute ( en m)
Y =np.array([................................................................])

# On parcourt la liste de t et Y pour calculer V,Ep,Ec et Em
for i in range(1,18):
  Vi=(Y[i+1]-Y[i-1])/(t[i+1]-t[i-1])
  Epi=...............
  Eci=...............
  Emi=..............

#On stoke chaque valeur dans des listes
  V.append(Vi)
  Ec.append(Eci)
  Ep.append(Epi)
  Em.append(Emi)
  tc.append(t[i])
#On affiche les différentes énergies en fct du temps de chute, tc
plt.plot(tc,Ec,'r-',label="Ec")
plt.plot(tc,Ep,'b--',label="Ep")
plt.plot(tc,Em,"g-", label="Em")
plt.title("Evolution des énergies mécaniques \n au cours du temps", fontsize=16)
plt.xlabel("Temps en s ")
plt.ylabel("Energie en Joules (J)")
plt.legend(loc= "upper right")
plt.grid()
# Out:
# Quelle est la masse du mobile étudié en kg ? 0.2
